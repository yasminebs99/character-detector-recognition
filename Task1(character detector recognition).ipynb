# %% [markdown]
# ### Import Libraries

# %%
pip install pytesseract
# Out:
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Uninstalling packaging-21.0:
#       Successfully uninstalled packaging-21.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import cv2
import pytesseract

# %%
# Set the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files (x86)/Tesseract-OCR/tesseract.exe'

# %% [markdown]
# ### Extract text from image

# %%
def extract_text_from_image(image_path):
    image = cv2.imread(image_path)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    threshold_image = cv2.threshold(gray_image, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
    extracted_text = pytesseract.image_to_string(threshold_image)
    return extracted_text

# %% [markdown]
# ### extract text from a video

# %%
def extract_text_from_video(video_path):
    video_capture = cv2.VideoCapture(video_path)
    extracted_text = ''
    # Loop through each frame in the video
    while True:
        ret, frame = video_capture.read()
        if not ret:
            break
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        threshold_frame = cv2.threshold(gray_frame, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
        text = pytesseract.image_to_string(threshold_frame)
        extracted_text += text
    # Release the video capture object
    video_capture.release()
    return extracted_text

# %% [markdown]
# ### Exemples

# %%
if __name__ == "__main__":
    image_path = 'C:/Users/ASUS/Desktop/TFS Foundation Tasks/Computer vision/img2.png'

    # Extract text from image
    extracted_text_image = extract_text_from_image(image_path)
    print("Text extracted from image:")
    print(extracted_text_image)
# Out:
# Text extracted from image:
# It was the best of
# times, it was the worst
# of times, it was the age
# ofwisdom, it was the
# age of foolishness".

# %%
if __name__ == "__main__":
    video_path = 'C:/Users/ASUS/Desktop/TFS Foundation Tasks/Computer vision/text vedio.mp4'
    #Extract text from video
    extracted_text_video = extract_text_from_video(video_path)
    print("Text extracted from video:")
    print(extracted_text_video)
# Out:
# Text extracted from video:
# 31:: IN 3::
# 3|] TRAILER TEXT EFFEETS IN 3[| SEEEINIJS
#
# www.NAWAZALAMl3|R.I:nM
#
# 31:: IN 31::
# 3[| TRAILER TEXT EFFEETS IN 3[| SEEEINDS
#
# www.NAWAZALAME|R.mM
#
# :30 IN :30
# 3|] TRMLER TEXT EFFEETS IN 3|] SEEIJNDS
#
# www.NAWAZALAM|3|R.nnM
#
# :3 III I N 3 El
# 3|] TRAILER TEXT EFFEETS IN 3|] SEEUNDS
#
# www.NAWAZALAM|3|R.nnM
#
# 31:: IN 3::
# 3H TRAILER TEXT EFFEETS IN 3[| SEEIJNDS
#
# www.NAWAZALAMB|R.cnM
#
# 3D IN 3D
# 3|] TRAILERTEXT EFFEET3 |N 3|] SEEIJNDS
#
# www.NAWAZALAME|R.nuM
#
# 3E| IN 30
# 3|] TRMLER TEXT EFFEET3 IN 3|] SEEIJNDS
#
# www.NAWAZALAME|R.nnM
#
# 3 CI I N 3 U
# 3|] TRNLER TEXT EFFEET3 |N 3[| SEEIJNDS
#
# www.NAWAZALAME|R.nuM
#
# 30 IN 30
# 3|] TIWLERTEXT EFFEETS IN 30 SEEIJNDS
#
# www.NAWAZALAM|3|R.cuM
#
# 30 IN 30
# 3|] TRAILER TEXT EFFEETS IN 3[| SEEIJNDS
#
# www.NAWAZALAM|3IR.I:nM
#
# 30 IN 3C|
# 3|] TRMLER TEXT EFFEETS |N 3[| SEEEINDS
#
# www.NAWAZALAMB|R.nuM
#
# 3 El I N 3 Cl
# 3|] TRMLERTEXT EFFEETS |N 3|] SEEIJNDS
# ...
